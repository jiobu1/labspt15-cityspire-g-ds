# %% [markdown]
# ## Creating schools.csv
#
# 1. Install packages
# 2. Create cities.csv with full state name/ city column to use in getting school information
# 3. For persisitance creating a schools csv using selenium to get school information from greatschools.org
# 4. Clean csv for use in schools endpoint

# %% [markdown]
# ### 1. Import necessary libraries

# %%
from bs4 import BeautifulSoup
import os
import requests
import csv
import json
import pandas as pd
from state_abbr import us_state_abbrev as abbr
from selenium import webdriver
import urllib.parse
import re
import html5lib
# Out:
# /Users/jisha/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ### 2.  Create cities.csv with full state name/ city column to use in getting school information

# %%
pwd = os.getcwd()

# create city state list
cities = pd.read_excel('notebooks/datasets/data/schools/csv/List of Cities.xlsx')

# just get the second and third colun
cities = cities[['Unnamed: 1','Unnamed: 2']]

# create new dictionary with reversed key, value pairs
full = dict(map(reversed, abbr.items()))

# map state abbreviations to full name
cities['states'] = cities['Unnamed: 2'].map(full)

# making sure state/city combo conform to url format of "-" for " "
cities['states'] = cities['states'].str.strip()
cities['states'] = cities['states'].str.replace(" ", "-")
cities['Unnamed: 1'] = cities['Unnamed: 1'].str.replace(" ", "-")

# remove extraneous header rows
cities = cities.iloc[2:]
cities['city'] = (cities['states'] + '/'+ cities['Unnamed: 1']).str.lower()
print(cities.head())

# persist by creating new csv
cities.to_csv('notebooks/datasets/data/schools/csv/cities.csv')

# %% [markdown]
# ### 3. For persisitance creating a schools csv using selenium and Beautiful Soup to get school information from greatschools.org

# %%
# Looping through each city in the file
# Call cities csv to get cities stored in database
cities = pd.read_csv('csv/cities.csv')

# Extracting school information
School = []
Score = []
Rating = []
Address = []

driver = webdriver.Chrome()

# url for greatschools pre_url and post_url (with state/city inbetween)
url_pre = 'http://www.greatschools.org/'

for i in cities['city']:
  fetching = True
  page = 0
  while fetching:  
        page += 1
        url = url_pre +  urllib.parse.quote(i) + '/schools/?page={}&tableView=Overview&view=table'.format(page)       
        print("Fetching ", url)

        driver.get(url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        # check if last page
        page_status = soup.find('div', {'class': 'pagination-summary'})
        page_status_text = page_status.text.strip()
        page_status_regex = re.search(r".* (\d+) to (\d+) of (\d+)", page_status_text)
        beginning, ending, total = page_status_regex.groups()
        if int(ending) >= int(total):
            fetching = False

        # appending school information for current cities
        # SCHOOL NAME
        for school in soup.find_all('a', {'class': 'name'}):
            School.append(school.text.strip())

        # RATING
        try: 
            for rating in soup.find_all('div', {'class': 'circle-rating--small'}):
                numeric = rating.text.strip()
                Rating.append(numeric)
        except AttributeError:
            numeric = 0

        # SCORE
        for score in soup.find_all('div', {'class': 'scale'}):
            Score.append(score.text.strip())

        # ADDRESS
        for address in soup.find_all('div', {'class': 'address'}):
            Address.append(address.text.strip())
        
driver.close()

schools = pd.DataFrame(list(zip(School, Score, Rating, Address)), columns = ['School', 'Score', 'Rating', 'Address'])

# %%
print(schools.shape)
schools.head()

# %%
# 5. For persisitance creating a schools csv
schools.to_csv('csv/schools_cleaned.csv')

# %%
# 6. Capturing the information for the remaining table separately
# Looping through each city in the file
# cities = pd.read_csv('csv/cities.csv')
cities = pd.read_csv('csv/cities.csv')

School = []

# create empty dataframe
df = pd.DataFrame()

driver = webdriver.Chrome()

# url for greatschools pre_url and post_url (with state/city inbetween)
url_pre = 'http://www.greatschools.org/'

for i in cities['city']:
  fetching = True
  page = 0
  while fetching:  
        page += 1
        url = url_pre +  urllib.parse.quote(i) + '/schools/?page={}&tableView=Overview&view=table'.format(page)       
        print("Fetching ", url)

        driver.get(url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        # check if last page
        page_status = soup.find('div', {'class': 'pagination-summary'})
        page_status_text = page_status.text.strip()
        print(page_status_text)
        page_status_regex = re.search(r".* (\d+) to (\d+) of (\d+)", page_status_text)
        beginning, ending, total = page_status_regex.groups()
        if int(ending) >= int(total):
            fetching = False

        table = pd.read_html(html)
        # appending to dataframe all the school information for current cities
        df = df.append(table[0])

        for school in soup.find_all('a', {'class': 'name'}):
            print(school.text.strip())
            School.append(school.text.strip())

driver.close()
# Out:
# ter
# Head Start
# Salmon Center For Early Ed
# Fetching  http://www.greatschools.org/michigan/wyoming/schools/?page=1&tableView=Overview&view=table
# Showing 1 to 25 of 50 schools found in Wyoming, MI
# Vanguard Charter Academy
# Grandville Century Park Learning Center
# West Godwin Elementary School
# Lee Middle School
# Grandville Grand View Elementary School
# Pinewood Middle School
# Rogers High School
# Lee High School
# Jackson Park Intermediate
# West Elementary School
# Newhall Middle School
# Parkview Elementary School
# Oriole Park Elementary School
# Godfrey Elementary School
# Valleywood Middle School
# San Juan Diego Academy
# Tri-Unity Christian Elementary School
# Spartan Stores Ymca Child Care Center
# Beech Head Start
# Appletree Christian Learning Center
# Hastings Day Care
# For the Kidz Gymnastics
# Wyoming Regional Center
# Godfrey-Lee Early Childhood Center
# St. John Vianney School
# Vanguard Charter Academy
# Grandville Century Park Learning Center
# West Godwin Elementary School
# Lee Middle School
# Grandville Grand View Elementary School
# Pinewood Middle School
# Rogers High School
# Lee High School
# Jackson Park Intermediate
# West Elementary School
# Newhall Middle School
# Parkview Elementary School
# Oriole Park Elementary School
# Godfrey Elementary School
# Valleywood Middle School
# San Juan Diego Academy
# Tri-Unity Christian Elementary School
# Spartan Stores Ymca Child Care Center
# Beech Head Start
# Appletree Christian Learning Center
# Hastings Day Care
# For the Kidz Gymnastics
# Wyoming Regional Center
# Godfrey-Lee Early Childhood Center
# St. John Vianney School
# Fetching  http://www.greatschools.org/michigan/wyoming/schools/?page=2&tableView=Overview&view=table
# Showing 26 to 50 of 50 schools found in Wyoming, MI
# Holy Trinity Evangelical Lutheran School
# Adams Protestant Reformed Christian School
# Tri-Unity Christian School
# Tri-Unity Christian Elementary School
# Holy Name of Jesus School
# SJV Caring Place Learning Cent
# Potters House High School
# East Lee Campus
# West Michigan Lutheran High School
# Kellogsville Early Cdc
# Oriole Park Pre-Kindergarten
# Grace Beginnings Pre-School
# East Child Care Center
# Godfrey Head Start Center
# Beverly Reformed Pre-School
# Southwest-Wyoming Co-Op
# Learn And Grow Child Care Center
# West Godwin Pre-School
# Wee Grow & Learn Child Care Center
# Happy Elephant Christian Dcc
# Godfrey Lee Pre-School
# Northwest Early Childhood Center
# Calvin Christian Elementary School
# Wyoming Community Educ. Center
# AnchorPoint Christian School
# Holy Trinity Evangelical Lutheran School
# Adams Protestant Reformed Christian School
# Tri-Unity Christian School
# Tri-Unity Christian Elementary School
# Holy Name of Jesus School
# SJV Caring Place Learning Cent
# Potters House High School
# East Lee Campus
# West Michigan Lutheran High School
# Kellogsville Early Cdc
# Oriole Park Pre-Kindergarten
# Grace Beginnings Pre-School
# East Child Care Center
# Godfrey Head Start Center
# Beverly Reformed Pre-School
# Southwest-Wyoming Co-Op
# Learn And Grow Child Care Center
# West Godwin Pre-School
# Wee Grow & Learn Child Care Center
# Happy Elephant Christian Dcc
# Godfrey Lee Pre-School
# Northwest Early Childhood Center
# Calvin Christian Elementary School
# Wyoming Community Educ. Center
# AnchorPoint Christian School
# Fetching  http://www.greatschools.org/washington/yakima/schools/?page=1&tableView=Overview&view=table
# Showing 1 to 25 of 106 schools found in Yakima, WA
# Apple Valley Elementary School
# Ahtanum Valley Elementary School
# East Valley Central Middle School
# Cottonwood Elementary School
# Mountainview Elementary School
# Summitview Elementary School
# Barge-Lincoln Elementary School
# Roosevelt Elementary School
# East Valley Intermediate School
# Franklin Middle School
# Whitney Elementary School
# Terrace Heights Elementary School
# West Valley Jr High School
# West Valley High School
# Nob Hill Elementary School
# Robertson Elementary School
# Wilson Middle School
# East Valley High School
# Wide Hollow Elementary School
# West Valley Middle School
# Adams Elementary School
# Garfield Elementary School
# Hoover Elementary School
# Discovery Lab School
# Ridgeview Elementary School
# Apple Valley Elementary School
# Ahtanum Valley Elementary School
# East Valley Central Middle School
# Cottonwood Elementary School
# Mountainview Elementary School
# Summitview Elementary School
# Barge-Lincoln Elementary School
# Roosevelt Elementary School
# East Valley Intermediate School
# Franklin Middle School
# Whitney Elementary School
# Terrace Heights Elementary School
# West Valley Jr High School
# West Valley High School
# Nob Hill Elementary School
# Robertson Elementary School
# Wilson Middle School
# East Valley High School
# Wide Hollow Elementary School
# West Valley Middle School
# Adams Elementary School
# Garfield Elementary School
# Hoover Elementary School
# Discovery Lab School
# Ridgeview Elementary School
# Fetching  http://www.greatschools.org/washington/yakima/schools/?page=2&tableView=Overview&view=table
# Showing 26 to 50 of 106 schools found in Yakima, WA
# Lewis & Clark Middle School
# Mcclure Elementary School
# Washington Middle School
# Davis High School
# Eisenhower High School
# Gilbert Elementary School
# McKinley Elementary School
# Stanton Alternative School
# Yakima Valley Technical Skills Center
# St Paul Cathedral School
# St Joseph Marquette Catholic School
# Grace Lutheran School
# Riverside Christian School
# Yakima Adventist Christian School
# Excel High School
# Ridgeview Group Home
# Montessori School of Yakima
# Oakridge Montessori School
# Early Childhood Center
# West Valley Preschool
# Yakima Valley Memorial Hospital Dba Children's Vil
# Green Pastures Learning Center
# Oakridge Ranch - Montessori Farm School
# St John Of Kionstadt Orthodox Christian School
# Epic Bridgeport Child Development Center
# Lewis & Clark Middle School
# Mcclure Elementary School
# Washington Middle School
# Davis High School
# Eisenhower High School
# Gilbert Elementary School
# McKinley Elementary School
# Stanton Alternative School
# Yakima Valley Technical Skills Center
# St Paul Cathedral School
# St Joseph Marquette Catholic School
# Grace Lutheran School
# Riverside Christian School
# Yakima Adventist Christian School
# Excel High School
# Ridgeview Group Home
# Montessori School of Yakima
# Oakridge Montessori School
# Early Childhood Center
# West Valley Preschool
# Yakima Valley Memorial Hospital Dba Children's Vil
# Green Pastures Learning Center
# Oakridge Ranch - Montessori Farm School
# St John Of Kionstadt Orthodox Christian School
# Epic Bridgeport Child Development Center
# Fetching  http://www.greatschools.org/washington/yakima/schools/?page=3&tableView=Overview&view=table
# Showing 51 to 75 of 106 schools found in Yakima, WA
# Epic Prosser Cdc
# Epic Sunnyside Cdc
# Taylor Tots Too Day Care
# Applke Valley Pre-School
# Judy's Junction
# Rainbow Kids Child Care Center
# Discovery House Pre-School & DC
# St Paul's Cathedral School
# La Petite Early Learning Center
# Wesley United Methodist Pre-School
# Stepping Stones Child Care Center
# Noahs Ark Child Care Center
# Yakima Valley Mem Hosp Elc
# Castlevale Migrant Head Start Center
# Taylor Tots Childcare
# Epic Childrens Village Tcd
# Joanna's Day Care
# Carroll Children's Center
# Country Kids Terrace Heights
# Crossroad Kids
# Sonshine Child Care Mt Olive
# Providence-Yakima Medical Day Care Center
# Country Kids Child Development Center
# Naches Youth Program Dc
# Wvcc Day Care-Wide Hollow
# Epic Prosser Cdc
# Epic Sunnyside Cdc
# Taylor Tots Too Day Care
# Applke Valley Pre-School
# Judy's Junction
# Rainbow Kids Child Care Center
# Discovery House Pre-School & DC
# St Paul's Cathedral School
# La Petite Early Learning Center
# Wesley United Methodist Pre-School
# Stepping Stones Child Care Center
# Noahs Ark Child Care Center
# Yakima Valley Mem Hosp Elc
# Castlevale Migrant Head Start Center
# Taylor Tots Childcare
# Epic Childrens Village Tcd
# Joanna's Day Care
# Carroll Children's Center
# Country Kids Terrace Heights
# Crossroad Kids
# Sonshine Child Care Mt Olive
# Providence-Yakima Medical Day Care Center
# Country Kids Child Development Center
# Naches Youth Program Dc
# Wvcc Day Care-Wide Hollow
# Fetching  http://www.greatschools.org/washington/yakima/schools/?page=4&tableView=Overview&view=table
# Showing 76 to 100 of 106 schools found in Yakima, WA
# WVCC Day Care-Ahtanum
# Wvcc Day Care-Mountain View
# Wvcc Dc-Apple Valley
# Wvcc Dc-Summitview
# Epic Child Care Center-Epic Place
# Epic Child Care Center-Prosser
# Epic Castlevale Head Start
# Epic CCC-Parker Heights
# Yakima Online!/Yakima Homeschool Partnership
# Christa McAuliffe Academy
# Yakima Kindercare
# Yakima Satellite Alternative Programs
# West Valley High School Freshman Campus
# Westpark Christian Academy
# The Learning Tree Kids Club
# Mount Olive Pre-School
# Ymca Base-Gilbert
# Ymca Base-Whitney
# Ymca Base Roosevelt
# Yakima Family Ymca
# Kids Inc Day Care
# Wonderland Pre-School
# Central Lutheran Pre-School
# Robyn's Day Care
# Fairview Head Start
# WVCC Day Care-Ahtanum
# Wvcc Day Care-Mountain View
# Wvcc Dc-Apple Valley
# Wvcc Dc-Summitview
# Epic Child Care Center-Epic Place
# Epic Child Care Center-Prosser
# Epic Castlevale Head Start
# Epic CCC-Parker Heights
# Yakima Online!/Yakima Homeschool Partnership
# Christa McAuliffe Academy
# Yakima Kindercare
# Yakima Satellite Alternative Programs
# West Valley High School Freshman Campus
# Westpark Christian Academy
# The Learning Tree Kids Club
# Mount Olive Pre-School
# Ymca Base-Gilbert
# Ymca Base-Whitney
# Ymca Base Roosevelt
# Yakima Family Ymca
# Kids Inc Day Care
# Wonderland Pre-School
# Central Lutheran Pre-School
# Robyn's Day Care
# Fairview Head Start
# Fetching  http://www.greatschools.org/washington/yakima/schools/?page=5&tableView=Overview&view=table
# Showing 101 to 106 of 106 schools found in Yakima, WA
# Jefferson Head Start
# St Joseph Pre-Kindergarten Center
# Ramirez Child Care Center
# Cottage Kids Childrens Center
# Buckle My Shoe Child Care Center
# Yakima Open Doors
# Jefferson Head Start
# St Joseph Pre-Kindergarten Center
# Ramirez Child Care Center
# Cottage Kids Childrens Center
# Buckle My Shoe Child Care Center
# Yakima Open Doors
# Fetching  http://www.greatschools.org/california/yuba-city/schools/?page=1&tableView=Overview&view=table
# Showing 1 to 25 of 62 schools found in Yuba City, CA
# Twin Rivers Charter School
# Franklin Elementary School
# River Valley High School
# Barry Elementary School
# Butte Vista Elementary School
# Lincoln Elementary School
# Tierra Buena Elementary School
# April Lane Elementary School
# Yuba City High School
# Riverbend Elementary School
# Yuba City Charter School
# Andros Karperos School
# Central Gaither Elementary School
# Gray Avenue Middle School
# Lincrest Elementary School
# Bridge Street Elementary School
# King Avenue Elementary School
# Park Avenue Elementary School
# Albert Powell Continuation School
# Sutter County Special Education School
# Tri-County Rop School
# First Baptist Academy
# Feather River Academy
# Little Rascals Pre-School
# Creative Kids/Pre-School
# Twin Rivers Charter School
# Franklin Elementary School
# River Valley High School
# Barry Elementary School
# Butte Vista Elementary School
# Lincoln Elementary School
# Tierra Buena Elementary School
# April Lane Elementary School
# Yuba City High School
# Riverbend Elementary School
# Yuba City Charter School
# Andros Karperos School
# Central Gaither Elementary School
# Gray Avenue Middle School
# Lincrest Elementary School
# Bridge Street Elementary School
# King Avenue Elementary School
# Park Avenue Elementary School
# Albert Powell Continuation School
# Sutter County Special Education School
# Tri-County Rop School
# First Baptist Academy
# Feather River Academy
# Little Rascals Pre-School
# Creative Kids/Pre-School
# Fetching  http://www.greatschools.org/california/yuba-city/schools/?page=2&tableView=Overview&view=table
# Showing 26 to 50 of 62 schools found in Yuba City, CA
# Jack And Jill Playschool
# New Adventures Pre-School
# Fusion Early Learning Preschools
# Mother Goose Nursery School
# Joyful Noise Nursery School
# Lincoln State Pre-School
# Grace Christian Pre-School
# Yuba City Migrant Head Start Center
# Guru Ram Das Khalsa Day Care-N California
# Kidz Town Pre-School Center
# Good Shepherd Nursery School
# Rainbow Montessori School
# East Center Head Start Program
# Migrant Child Care/St. Pre-School
# Big Kid Zone Day Care
# Son Shine Nursery School
# Leeanne's Day Care Home
# Creative Kids-Pre-School
# Yuba City Unified Alternative School
# Covenant Christian
# Basics & Beyond Private Ed
# Sutter County Adult
# California Technical Education Center
# Yuba Sutter Rainbow Mont School
# Kidz Town Pre-School
# Jack And Jill Playschool
# New Adventures Pre-School
# Fusion Early Learning Preschools
# Mother Goose Nursery School
# Joyful Noise Nursery School
# Lincoln State Pre-School
# Grace Christian Pre-School
# Yuba City Migrant Head Start Center
# Guru Ram Das Khalsa Day Care-N California
# Kidz Town Pre-School Center
# Good Shepherd Nursery School
# Rainbow Montessori School
# East Center Head Start Program
# Migrant Child Care/St. Pre-School
# Big Kid Zone Day Care
# Son Shine Nursery School
# Leeanne's Day Care Home
# Creative Kids-Pre-School
# Yuba City Unified Alternative School
# Covenant Christian
# Basics & Beyond Private Ed
# Sutter County Adult
# California Technical Education Center
# Yuba Sutter Rainbow Mont School
# Kidz Town Pre-School
# Fetching  http://www.greatschools.org/california/yuba-city/schools/?page=3&tableView=Overview&view=table
# Showing 51 to 62 of 62 schools found in Yuba City, CA
# West Walton State Pre-School
# Little Tots Playcare
# Kids Time Pre School
# Kidz Time Ii Day Care
# Harvest Church
# Orchard Creek Academy
# Yuba City Special Education Preschool
# St. Isidore Catholic School
# Faith Christian Schools
# Adventist Christian School
# Grace Christian Academy
# Faith Christian Junior-Senior High School
# West Walton State Pre-School
# Little Tots Playcare
# Kids Time Pre School
# Kidz Time Ii Day Care
# Harvest Church
# Orchard Creek Academy
# Yuba City Special Education Preschool
# St. Isidore Catholic School
# Faith Christian Schools
# Adventist Christian School
# Grace Christian Academy
# Faith Christian Junior-Senior High School
# Fetching  http://www.greatschools.org/arizona/yuma/schools/?page=1&tableView=Overview&view=table
# Showing 1 to 25 of 109 schools found in Yuma, AZ
# Desert View Academy
# Gowan Science Academy
# Cibola High School
# Amerischools Academy North
# Alice Byrne Elementary School
# Desert Mesa Elementary School
# O C Johnson School
# Pueblo Elementary School
# Roosevelt School
# Sunrise Elementary School
# Gila Ridge High School
# Mesquite Elementary School
# C W Mcgraw Elementary School
# Centennial Middle School
# Crane Middle School
# Kofa High School
# Mary A Otondo Elementary School
# Carpe Diem Collegiate High School Dba Carpe Diem E
# H L Suverkrup Elementary School
# James B Rolle School
# Palmcroft Elementary School
# Ronald Reagan Fundamental School
# Yuma High School
# Harvest Preparatory Academy
# Gary A. Knox Elementary School
# Desert View Academy
# Gowan Science Academy
# Cibola High School
# Amerischools Academy North
# Alice Byrne Elementary School
# Desert Mesa Elementary School
# O C Johnson School
# Pueblo Elementary School
# Roosevelt School
# Sunrise Elementary School
# Gila Ridge High School
# Mesquite Elementary School
# C W Mcgraw Elementary School
# Centennial Middle School
# Crane Middle School
# Kofa High School
# Mary A Otondo Elementary School
# Carpe Diem Collegiate High School Dba Carpe Diem E
# H L Suverkrup Elementary School
# James B Rolle School
# Palmcroft Elementary School
# Ronald Reagan Fundamental School
# Yuma High School
# Harvest Preparatory Academy
# Gary A. Knox Elementary School
# Fetching  http://www.greatschools.org/arizona/yuma/schools/?page=2&tableView=Overview&view=table
# Showing 26 to 50 of 109 schools found in Yuma, AZ
# Salida Del Sol Elementary School
# Ron Watson Middle School
# Castle Dome Middle School
# George Washington Carver Elementary School
# Gila Vista Junior High School
# R Pete Woodard Jr High School
# Rancho Viejo Elementary School
# Valley Horizon Elementary School
# Fourth Avenue Junior High School
# Amerischools Academy - Yuma
# Aztec High School
# Educational Opportunity Center
# James D Price School
# Pecan Grove Elementary School
# Vista Alternative School
# Immaculate Conception Elementary School
# St. Francis of Assisi School
# Yuma Lutheran School
# Yuma Adventist Christian School
# Calvary Baptist School
# Southwestern Christian School
# Yuma Catholic High School
# Little Gems Pre-School
# Northend Pre-School 1
# Ojeda Group Home
# Salida Del Sol Elementary School
# Ron Watson Middle School
# Castle Dome Middle School
# George Washington Carver Elementary School
# Gila Vista Junior High School
# R Pete Woodard Jr High School
# Rancho Viejo Elementary School
# Valley Horizon Elementary School
# Fourth Avenue Junior High School
# Amerischools Academy - Yuma
# Aztec High School
# Educational Opportunity Center
# James D Price School
# Pecan Grove Elementary School
# Vista Alternative School
# Immaculate Conception Elementary School
# St. Francis of Assisi School
# Yuma Lutheran School
# Yuma Adventist Christian School
# Calvary Baptist School
# Southwestern Christian School
# Yuma Catholic High School
# Little Gems Pre-School
# Northend Pre-School 1
# Ojeda Group Home
# Fetching  http://www.greatschools.org/arizona/yuma/schools/?page=3&tableView=Overview&view=table
# Showing 51 to 75 of 109 schools found in Yuma, AZ
# Cornerstone Pre-School
# The Learning Pad Christian Preschool and Kindergarten
# Whiz Kids
# Hand In Hand Pre-School
# Centeno R Child Care
# Kiara's Day Care
# Ruvalcaba Day Care
# Our Pad Day Care
# Bubbles Child Care Center
# Mi Casa Day Care
# Wacog-24th St Head Start
# Chicanos Por La Causa Head
# Young Minds Pre-School
# Alicias Day Care
# LTL Sprouts Complete Child Care
# Faly's Child Care Center
# Desert Mesa Es Day Care
# Little Einstein Child Care
# Kelland's Kiddie College
# Irene's Child Care Center
# Jacara E Safrit Day Care
# Wickenburg Head Start
# Whiz Kids II
# Wacog Foothills Head Start
# Us Army Proving Grnd Cdc
# Cornerstone Pre-School
# The Learning Pad Christian Preschool and Kindergarten
# Whiz Kids
# Hand In Hand Pre-School
# Centeno R Child Care
# Kiara's Day Care
# Ruvalcaba Day Care
# Our Pad Day Care
# Bubbles Child Care Center
# Mi Casa Day Care
# Wacog-24th St Head Start
# Chicanos Por La Causa Head
# Young Minds Pre-School
# Alicias Day Care
# LTL Sprouts Complete Child Care
# Faly's Child Care Center
# Desert Mesa Es Day Care
# Little Einstein Child Care
# Kelland's Kiddie College
# Irene's Child Care Center
# Jacara E Safrit Day Care
# Wickenburg Head Start
# Whiz Kids II
# Wacog Foothills Head Start
# Us Army Proving Grnd Cdc
# Fetching  http://www.greatschools.org/arizona/yuma/schools/?page=4&tableView=Overview&view=table
# Showing 76 to 100 of 109 schools found in Yuma, AZ
# Lucia Arrizon Day Care
# Yuma Head Start-Helping Hands
# Julia M Padilla Day Care
# Desert Trails
# Ysd Gwyneth Pre-School
# Wacog Head Start-Yuma East
# Yuma Pre-School & Day Care
# Wacog Head Start-Rancho Viejo
# Az Western College Child Development Center
# Discovery Club CCC-Sunrise
# Ischool2020
# Yuma Online Distance Academy
# Southwest Region
# Casa De Ninos Pre-School
# Pre-School Express Llc
# Little Explorers
# Luz's Child Care Center
# Angelical Day Care
# Magic Rainbow Day Care
# Kids Space Day Care
# Tender Hearts Pre-School & Dc
# Happy Face Day Care
# Y Kidz-Gary Knox Pk
# Treehouse Kids Club Pk
# Harvest Pre-School & Child Care Center
# Lucia Arrizon Day Care
# Yuma Head Start-Helping Hands
# Julia M Padilla Day Care
# Desert Trails
# Ysd Gwyneth Pre-School
# Wacog Head Start-Yuma East
# Yuma Pre-School & Day Care
# Wacog Head Start-Rancho Viejo
# Az Western College Child Development Center
# Discovery Club CCC-Sunrise
# Ischool2020
# Yuma Online Distance Academy
# Southwest Region
# Casa De Ninos Pre-School
# Pre-School Express Llc
# Little Explorers
# Luz's Child Care Center
# Angelical Day Care
# Magic Rainbow Day Care
# Kids Space Day Care
# Tender Hearts Pre-School & Dc
# Happy Face Day Care
# Y Kidz-Gary Knox Pk
# Treehouse Kids Club Pk
# Harvest Pre-School & Child Care Center
# Fetching  http://www.greatschools.org/arizona/yuma/schools/?page=5&tableView=Overview&view=table
# Showing 101 to 109 of 109 schools found in Yuma, AZ
# Happy Faces Day Care
# Bright Beginnings Child Care Center
# Yuma District One Digital Learning Academy
# Stedy- Vista High Satellite
# Stedy- Cibola High School Satellite
# Stedy- Yuma High Satellite
# Stedy- Kofa High Satellite
# Stedy- Gila Ridge High Satellite
# Crane Ilearning Academy
# Happy Faces Day Care
# Bright Beginnings Child Care Center
# Yuma District One Digital Learning Academy
# Stedy- Vista High Satellite
# Stedy- Cibola High School Satellite
# Stedy- Yuma High Satellite
# Stedy- Kofa High Satellite
# Stedy- Gila Ridge High Satellite
# Crane Ilearning Academy

# %%
column_values = pd.Series(School)

# %%
column_values.to_csv('school_name.csv')

# %%
df.to_csv('schools.csv')

# %%
df.insert(loc=0, column='School Name', value=column_values)

# %%
df.head()
# Out:
#                            School Name  \
# 0      Akron Early College High School
# 1                 Revere Middle School
# 2  Arrowhead Primary Elementary School
# 3             Manchester Middle School
# 4             Nolley Elementary School
#
#                                               School             Type Grades  \
# 0  10/10Top ratedAkron Early College High School2...  Public district   9-12
# 1  9/10Above averageRevere Middle School3195 Spri...  Public district    6-8
# 2  8/10Above averageArrowhead Primary Elementary ...  Public district    K-4
# 3  8/10Above averageManchester Middle School760 W...  Public district    5-8
# 4  8/10Above averageNolley Elementary School6285 ...  Public district    K-4
#
#    Total students enrolled Students per teacher    Reviews  \
# 0                    384.0                 34:1  8 reviews
# 1                    624.0                 13:1   1 review
# 2                    345.0                 20:1  6 reviews
# 3                    387.0                 16:1  2 reviews
# 4                    483.0                 17:1  2 reviews
#
#                                District
# 0            Akron City School District
# 1          Revere Local School District
# 2  Copley-Fairlawn City School District
# 3      Manchester Local School District
# 4      Manchester Local School District

# %%
schools = pd.read_csv('csv/schools_cleaned.csv')

# %%
schools = schools.rename(columns = {'School': 'School Name'})

# %%
schools = schools.merge(df, on=['School Name'])

# %%
schools.head()
# Out:
#    Unnamed: 0                      School Name      Score Rating  \
# 0           0  Akron Early College High School  Top rated  10/10
# 1           0  Akron Early College High School  Top rated  10/10
# 2           0  Akron Early College High School  Top rated  10/10
# 3           0  Akron Early College High School  Top rated  10/10
# 4           0  Akron Early College High School  Top rated  10/10
#
#                                    Address  \
# 0  225 South Main Street, Akron, OH, 44308
# 1  225 South Main Street, Akron, OH, 44308
# 2  225 South Main Street, Akron, OH, 44308
# 3  225 South Main Street, Akron, OH, 44308
# 4  225 South Main Street, Akron, OH, 44308
#
#                                               School             Type Grades  \
# 0  10/10Top ratedAkron Early College High School2...  Public district   9-12
# 1  4/10Below averageBetty Jane Community Learning...  Public district    K-5
# 2  3/10Below averageRoosevelt Elementary School66...  Public district   PK-3
# 3  Currently unratedWonder World Infant Dcc1360 E...          Private     PK
# 4  Currently unratedNordonia Hills Ymca Day Care2...          Private     PK
#
#    Total students enrolled Students per teacher         Reviews  \
# 0                    384.0                 34:1       8 reviews
# 1                    453.0                 16:1       6 reviews
# 2                    409.0                 17:1  No reviews yet
# 3                      NaN                  NaN  No reviews yet
# 4                      NaN                  NaN  No reviews yet
#
#                             District
# 0         Akron City School District
# 1         Akron City School District
# 2  Springfield Local School District
# 3                                NaN
# 4                                NaN

# %%
print(schools.shape)
# Out:
# (126272, 12)

# %%
schools.to_csv('new_schools.csv')
